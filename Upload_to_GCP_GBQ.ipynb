# %%
from pandas.io import gbq
import pandas_gbq
import pandas as pd

# %%
table_id = 'outstanding-pen-377709.faizan_dataset.my_gbq_table2023'

# %%
schema = [
    {"time_local": "col1", "type": "DATETIME"},
    #{'name':"time_local", 'type':'DATETIME' }
    {"alias": "col2", "type": "STRING"},
    {"value": "col3", "type": "FLOAT"}
]

# %%
#gbq.create_empty_table(table_id, schema)

# %%
#Method 1 
table_id = 'outstanding-pen-377709.faizan_dataset.my_gbq_table002'
df = pd.read_csv("D:\\Thermosphr\\KPI_task\\file.csv")
df.to_gbq(table_id, if_exists="fail")
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\bigquery\client.py:2456, in Client.load_table_from_file(self, file_obj, destination, rewind, size, num_retries, job_id, job_id_prefix, location, project, job_config, timeout)
#    2455     else:
# -> 2456         response = self._do_multipart_upload(
#    2457             file_obj, job_resource, size, num_retries, timeout, project=project
#    2458         )
#    2459 except resumable_media.InvalidResponse as exc:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\bigquery\client.py:3026, in Client._do_multipart_upload(self, stream, metadata, size, num_retries, timeout, project)
#    3022     upload._retry_strategy = resumable_media.RetryStrategy(
#    3023         max_retries=num_retries
#    3024     )
# ...

# %%
df1 = pd.read_csv("D:\\Thermosphr\\KPI_task\\main_data.csv")
table_id1 = 'outstanding-pen-377709.faizan_dataset.my_gbq_table001'

# %%
#method 2 
pandas_gbq.to_gbq(df1, table_id1)

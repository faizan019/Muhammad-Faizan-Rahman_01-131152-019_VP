# %%
import firebase_admin
from firebase_admin import credentials


#fetvhing the service account key in JSON format
cred = credentials.Certificate("D:\\Thermosphr\\fir-project-9ba07-d02e02746cdc.json")
firebase_admin.initialize_app(cred)

# %%
read = db.collection('clients_config').document('gera-arcaden-germany').get().to_dict()
print(read)
# Out:
# {'date_update': DatetimeWithNanoseconds(2023, 2, 20, 5, 22, 12, 119537, tzinfo=datetime.timezone.utc), 'client_id': 'gera-arcaden-germany', 'is_enabled': True}

# %%
doc_ref = db.collection('clients_config').document('gera-arcaden-germany').collection('sub_configs').document('kpi_config')
doc1 = doc_ref.get()
if doc1.exists:
    print(f'Document data: {doc1.to_dict()}')
else:
    print('No such document!')
# Out:
# Document data: {'rules': {'kpi_name': {'15': 'predicted_heat_kwh', '16': 'baseline_heat_kwh', '6': 'outside_air_temp_mean', '5': 'hx_2_hot_water_delta_temp_sum', '10': 'co2_ppm_fraction_<500ppm', '11': 'co2_ppm_mean', '13': 'HDD_15C_COSTIC', '7': 'outside_air_temp_max', '9': 'CDD_15C', '1': 'run_time_hours', '2': 'run_time_fraction', '14': 'hot_water_temp_mean', '8': 'HDD_15C', '3': 'ahu_air_return_temp_fraction_18C-24C', '12': 'ahu_air_return_temp_mean', '4': 'hx_1_hot_water_delta_temp_sum'}, 'start_time': {'15': None, '16': None, '6': None, '5': None, '10': None, '11': None, '13': None, '7': None, '9': None, '1': None, '2': None, '14': None, '12': None, '3': None, '8': None, '4': None}, 'alias_c': {'10': None, '16': None, '6': None, '5': 'heatExchanger_2_primaryLoop_hot_water_valve_sp', '15': 'heatExchanger_2_primaryLoop_hot_water_leaving_temp_sensor', '11': None, '13': None, '7': None, '9': None, '1': None, '2': None, '14': None, '8': None, '3': None, '12': None, '4': 'heatExchang
# ...

# %%
# Get all documents from the "clients_config" collection
collection_ref = db.collection('clients_config')
docs = collection_ref.get()
for doc in docs:
    print(u'{} => {}'.format(doc.id, doc.to_dict()))

    
# Get all documents from the "sub_configs" subcollection of this document
subcollection_ref = doc.reference.collection('sub_configs')
subdocs = subcollection_ref.get()
for subdoc in subdocs:
    print(u'{} => {}'.format(subdoc.id, subdoc.to_dict()))

# %%
# collection_ref = db.collection('clients_config').document('gera-arcaden-germany')
# docs = collection_ref.get()
# for doc in docs:
#     data = doc.to_dict()
#     print(json.dumps(data, indent =4, default=str))
#     subcollection_ref = doc.reference.collection('sub_configs').document('kpi_config')
#     subdocs = subcollection_ref.get()
#     for subdoc in subdocs:
#         subdata = subdoc.to_dict()
#         print(json.dumps(subdata, indent =4))

# %%
# from firebase_admin import db
# from google.cloud import firestore

# db = firestore.Client()

# collection = db.collection('programmer_details')  # create collection
# res = collection.document('A01').set({ # insert document
#     'name': 'ali',
#     'age': 19,
#     'Country': 'Pak',
#     'Programming_languages': ['Python', 'C#', 'C++']
# })
# print(res)

# %%
# from google.cloud import firestore
# db = firestore.Client()
# users_ref = db.collection('users')
# docs = users_ref.stream()
# for doc in docs:
#     doc.reference.delete()

# # Delete the "users" collection
# db.collection('users').delete()

# %%
#reading a firestore database 
import json
from google.cloud import firestore


# Get the document with ID "document_id" from the "clients_config" collection
doc_ref = db.collection('clients_config').document('gera-arcaden-germany')
doc = doc_ref.get()

if doc.exists:
    # Get the document with ID "subdocument_id" from the "sub_configs" subcollection of this document
    subdoc_ref = doc_ref.collection('sub_configs').document('kpi_config')
    subdoc = subdoc_ref.get()
    
    if subdoc.exists:
        # Merge the data from the two documents into a single dictionary
        data = doc.to_dict()
        data['kpi_config'] =subdoc.to_dict()
        #data.update(subdoc.to_dict())

        # Print the combined data as a JSON string
        print(json.dumps(data, indent=4, default= str))
    else:
        print('Subdocument does not exist.')
else:
    print('Document does not exist.')
# Out:
# {
#     "date_update": "2023-02-20 08:01:03.262714+00:00",
#     "client_id": "gera-arcaden-germany",
#     "is_enabled": true,
#     "kpi_config": {
#         "rules": {
#             "kpi_name": {
#                 "15": "predicted_heat_kwh",
#                 "16": "baseline_heat_kwh",
#                 "6": "outside_air_temp_mean",
#                 "5": "hx_2_hot_water_delta_temp_sum",
#                 "10": "co2_ppm_fraction_<500ppm",
#                 "11": "co2_ppm_mean",
#                 "13": "HDD_15C_COSTIC",
#                 "7": "outside_air_temp_max",
#                 "9": "CDD_15C",
#                 "1": "run_time_hours",
#                 "2": "run_time_fraction",
#                 "14": "hot_water_temp_mean",
#                 "8": "HDD_15C",
#                 "3": "ahu_air_return_temp_fraction_18C-24C",
#                 "4": "hx_1_hot_water_delta_temp_sum",
#                 "12": "ahu_air_return_temp_mean"
#             },
#             "start_time": {
# ...

# %%
from google.cloud import firestore

# Initialize Firestore Client
db = firestore.Client()

# Get a reference to the sub-collection
subcollection_ref = db.collection('clients_config').document('gera-arcaden-germany').collection('sub_configs')

# Add a new document to the sub-collection
# subcollection_ref.add({
#     'field1': 'value1',
#     'field2': 'value2'
# }, document_id='my_document_id')



# json_data = '{"_comment_":"This is QA settings","settings":{"mute_rules":false,"station_id":"10567","country":"Germany","state":"TH"},"rules":{"rule_name":{"1":"ahu_cmd_enabled_24h","2":"ahu_cmd_enabled_72h","3":"ahu_enabled_24h","4":"ahu_enabled_72h","5":"chiller_enabled_24h","6":"chiller_enabled_72h","7":"chilled_water_pump_enabled_24h","8":"chilled_water_pump_enabled_72h","9":"condenser_water_pump_enabled_24h","10":"condenser_water_pump_enabled_72h","11":"coolingTower_enabled_24h","12":"coolingTower_enabled_72h","13":"boiler_enabled_24h","14":"boiler_enabled_72h","15":"heat_pump_enabled_24h","16":"heat_pump_enabled_72h","17":"hot_water_pump_enabled_72h","18":"air_flow_>75perc_4h","19":"air_flow_>75perc_8h","20":"chilled_hot_water_valve_>50perc_1h","21":"chilled_hot_water_valve_>50perc_4h","22":"hot_water_valve_not_closing_1h","23":"hot_water_valve_not_closing_4h","24":"hot_water_valve_>90perc_2h","25":"hot_water_valve_>90perc_8h","26":"chilled_water_valve_>90perc_2h","27":"chilled_water_valve_>90perc_8h","28":"zone_air_temp_>28C_2h","29":"zone_air_temp_>28C_4h","30":"zone_air_temp_<15C_2h","31":"zone_air_temp_<15C_4h","32":"discharge_air_temp_>40C_2h","33":"discharge_air_temp_>40C_4h","34":"discharge_air_temp_<10C_2h","35":"discharge_air_temp_<10C_4h","36":"chilled_water_valve_not_closing_1h","37":"chilled_water_valve_not_closing_4h","38":"chilled_water_valve_not_opening_1h","39":"chilled_water_valve_not_opening_4h","40":"hot_water_valve_not_opening_1h","41":"hot_water_valve_not_opening_4h","42":"water_almost_boiling_2h","43":"water_almost_boiling_4h","44":"water_almost_freezing_2h","45":"water_almost_freezing_4h","46":"pump_speed_>90perc_4h","47":"pump_speed_>90perc_8h","48":"fan_speed_>90perc_4h","49":"fan_speed_>90perc_8h","50":"constant_ahu_air_discharge_temp_sp","51":"constant_hot_water_temp_sp","52":"constant_chilled_water_temp_sp","53":"constant_ahu_air_flow_sp","54":"missing_values_3h","55":"missing_values_6h","56":"temp_sensor_<-40_3h","57":"temp_sensor_<-40_6h","58":"negative_values_3h","59":"negative_values_6h","60":"constant_values_24h","61":"constant_values_48h","62":"temp_sensor_>100_3h","63":"temp_sensor_>100_6h","64":"zone_office_hot_water_temp_low_1h","65":"heat_exchanger_1_hot_water_temp_low_1h","66":"heat_exchanger_2_hot_water_temp_low_1h","67":"heat_exchanger_pump_pressure_<0.45bar_1h","68":"ahu_air_return_temp_<16C_2h","69":"zone_office_pump_enable_sensor_OFF_1h","70":"zone_office_hot_water_alarm_ON_30m","71":"zone_office_water_valve_sp_>95perc_1h","72":"kaufland_air_discharge_temp<15C_1h","73":"customer_center_hot_water_temp_low_1h"},"alias_a":{"1":"ahu_enable_cmd","2":"ahu_enable_cmd","3":"ahu_enable_sensor","4":"ahu_enable_sensor","5":"chiller_enable_sensor","6":"chiller_enable_sensor","7":"chilled_water_pump_enable_sensor","8":"chilled_water_pump_enable_sensor","9":"condenser_water_pump_enable_sensor","10":"condenser_water_pump_enable_sensor","11":"coolingTower_enable_sensor","12":"coolingTower_enable_sensor","13":"boiler_enable_sensor","14":"boiler_enable_sensor","15":"heatPump_enable_sensor","16":"heatPump_enable_sensor","17":"hot_water_enable_sensor","18":"air_flow_sp","19":"air_flow_sp","20":"ahu_chilled_water_valve_sp","21":"ahu_chilled_water_valve_sp","22":"ahu_discharge_air_temp_sensor","23":"ahu_discharge_air_temp_sensor","24":"ahu_hot_water_valve_sp","25":"ahu_hot_water_valve_sp","26":"ahu_chilled_water_valve_sp","27":"ahu_chilled_water_valve_sp","28":"zone_air_return_temp_sensor","29":"zone_air_return_temp_sensor","30":"zone_air_return_temp_sensor","31":"zone_air_return_temp_sensor","32":"ahu_discharge_air_temp_sensor","33":"ahu_discharge_air_temp_sensor","34":"ahu_discharge_air_temp_sensor","35":"ahu_discharge_air_temp_sensor","36":"ahu_discharge_air_temp_sensor","37":"ahu_discharge_air_temp_sensor","38":"ahu_discharge_air_temp_sensor","39":"ahu_discharge_air_temp_sensor","40":"ahu_discharge_air_temp_sensor","41":"ahu_discharge_air_temp_sensor","42":"water_temp_sensor","43":"water_temp_sensor","44":"water_temp_sensor","45":"water_temp_sensor","46":"water_flow_sp","47":"water_flow_sp","48":"air_flow_sp","49":"air_flow_sp","50":"ahu_air_discharge_temp_sp","51":"hot_water_temp_sp","52":"chilled_water_temp_sp","53":"air_flow_sp","54":null,"55":null,"56":"temp_sensor","57":"temp_sensor","58":"-temp","59":"-temp","60":"temp_sensor","61":"temp_sensor","62":"temp_sensor","63":"temp_sensor","64":"zone_office_hot_water_entering_temp_sensor","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sensor","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sensor","67":"heatExchanger_pump_hot_water_delta_pressure_sensor","68":"ahu_air_return_temp_sensor","69":"zone_office_pump_hot_water_enable_sensor","70":"zone_office_pump_hot_water_alarm","71":"zone_office_hot_water_valve_sp","72":"ahu_212_air_discharge_temp_sensor","73":"zone_7_heatExchanger_2_hot_water_entering_temp_sensor"},"alias_b":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_hot_water_valve_sp","21":"ahu_hot_water_valve_sp","22":"ahu_hot_water_valve_sp","23":"ahu_hot_water_valve_sp","24":"ahu_fan_air_return_enable_cmd","25":"ahu_fan_air_return_enable_cmd","26":"ahu_fan_air_return_enable_cmd","27":"ahu_fan_air_return_enable_cmd","28":"ahu_fan_air_return_enable_cmd","29":"ahu_fan_air_return_enable_cmd","30":"ahu_fan_air_return_enable_cmd","31":"ahu_fan_air_return_enable_cmd","32":"ahu_fan_air_discharge_enable_cmd","33":"ahu_fan_air_discharge_enable_cmd","34":"ahu_fan_air_discharge_enable_cmd","35":"ahu_fan_air_discharge_enable_cmd","36":"ahu_chilled_water_valve_sp","37":"ahu_chilled_water_valve_sp","38":"ahu_chilled_water_valve_sp","39":"ahu_chilled_water_valve_sp","40":"ahu_hot_water_valve_sp","41":"ahu_hot_water_valve_sp","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"zone_office_hot_water_entering_temp_sp","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sp","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sp","67":"heatExchanger_pump_hot_water_enable_cmd","68":"ahu_fan_air_return_enable_cmd","69":null,"70":null,"71":"heatExchanger_pump_hot_water_enable_cmd ","72":null,"73":"zone_7_heatExchanger_2_hot_water_entering_temp_sp"},"alias_c":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_enable_sensor","21":"ahu_enable_sensor","22":"ahu_enable_sensor","23":"ahu_enable_sensor","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"ahu_enable_sensor","37":"ahu_enable_sensor","38":"ahu_enable_sensor","39":"ahu_enable_sensor","40":"ahu_enable_sensor","41":"ahu_enable_sensor","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_1_primaryLoop_hot_water_valve_sp","65":"heatExchanger_1_primaryLoop_hot_water_valve_sp","66":"heatExchanger_1_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_1_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_1_primaryLoop_hot_water_valve_sp"},"alias_d":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":"outside_air_temp","23":"outside_air_temp","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"outside_air_temp","37":"outside_air_temp","38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_2_primaryLoop_hot_water_valve_sp","65":"heatExchanger_2_primaryLoop_hot_water_valve_sp","66":"heatExchanger_2_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_2_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_2_primaryLoop_hot_water_valve_sp"},"equation_1":{"1":"alias_a > 0","2":"alias_a > 0","3":"alias_a > 0","4":"alias_a > 0","5":"alias_a > 0","6":"alias_a > 0","7":"alias_a > 0","8":"alias_a > 0","9":"alias_a > 0","10":"alias_a > 0","11":"alias_a > 0","12":"alias_a > 0","13":"alias_a > 0","14":"alias_a > 0","15":"alias_a > 0","16":"alias_a > 0","17":"alias_a > 0","18":"alias_a > 75","19":"alias_a > 75","20":"alias_a > 50 and alias_b > 50 and alias_c == 1","21":"alias_a > 50 and alias_b > 50 and alias_c == 1","22":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","23":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","24":"alias_a > 90 and alias_b ==1","25":"alias_a > 90 and alias_b ==1","26":"alias_a > 90 and alias_b ==1","27":"alias_a > 90 and alias_b ==1","28":"alias_a > 28 and alias_b ==1","29":"alias_a > 28 and alias_b ==1","30":"alias_a < 15 and alias_b == 1","31":"alias_a < 15 and alias_b == 1","32":"alias_a > 40 and alias_b == 1","33":"alias_a > 40 and alias_b == 1","34":"alias_a < 10 and alias_b ==1 ","35":"alias_a < 10 and alias_b ==1 ","36":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","37":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","38":"alias_a > 20 and alias_b > 90 and alias_c ==1","39":"alias_a > 20 and alias_b > 90 and alias_c ==2","40":"alias_a < 20 and alias_b > 90 and alias_c ==1","41":"alias_a < 20 and alias_b > 90 and alias_c ==1","42":"alias_a > 90","43":"alias_a > 90","44":"alias_a < 5","45":"alias_a < 5","46":"alias_a >= 90","47":"alias_a >= 90","48":"alias_a >= 90","49":"alias_a >= 90","50":null,"51":null,"52":null,"53":null,"54":"pd.isna(alias_a)","55":"pd.isna(alias_a)","56":"alias_a < -40","57":"alias_a < -40","58":"alias_a < 0","59":"alias_a < 0","60":null,"61":null,"62":"alias_a > 100","63":"alias_a > 100","64":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4","65":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","66":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","67":"alias_a < 0.45 and alias_b ==1","68":"alias_a < 16 and alias_b==1","69":"alias_a==0","70":"alias_a != 1","71":"alias_a>95 and alias_b == 1 and (alias_c > 10 or alias_d > 10)","72":"alias_a<15","73":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4"},"equation_2":{"1":"streak >= 24","2":"streak >= 72","3":"streak >= 24","4":"streak >= 72","5":"streak >= 24","6":"streak >= 72","7":"streak >= 24","8":"streak >= 72","9":"streak >= 24","10":"streak >= 72","11":"streak >= 24","12":"streak >= 72","13":"streak >= 24","14":"streak >= 72","15":"streak >= 24","16":"streak >= 72","17":"streak >= 72","18":"streak >= 4","19":"streak >= 8","20":"streak >= 1","21":"streak >= 4","22":"streak >= 1","23":"streak >= 4","24":"streak >= 2","25":"streak >= 8","26":"streak >= 2","27":"streak >= 8","28":"streak >= 2","29":"streak >= 4","30":"streak >= 2","31":"streak >= 4","32":"streak >= 2","33":"streak >= 4","34":"streak >= 2","35":"streak >= 4","36":"streak >= 1","37":"streak >= 4","38":"streak >= 1","39":"streak >= 4","40":"streak >= 1","41":"streak >= 4","42":"streak >= 2","43":"streak >= 4","44":"streak >= 2","45":"streak >= 4","46":"streak >= 4","47":"streak >= 8","48":"streak >= 4","49":"streak >= 8","50":"std == 0","51":"std == 0","52":"std == 0","53":"std == 0","54":"streak >= 3","55":"streak >= 6","56":"streak >= 3","57":"streak >= 6","58":"streak >= 3","59":"streak >= 6","60":"std == 0","61":"std == 0","62":"streak >= 3","63":"streak >= 6","64":"streak >= 1","65":"streak >= 1","66":"streak >= 1","67":"streak >= 1","68":"streak >= 2","69":"streak >= 1","70":"streak >= 0.5","71":"streak >= 1","72":"streak >= 1","73":"streak >= 1"},"duration_hours":{"1":24,"2":72,"3":24,"4":72,"5":24,"6":72,"7":24,"8":72,"9":24,"10":72,"11":24,"12":72,"13":24,"14":72,"15":24,"16":72,"17":72,"18":8,"19":16,"20":2,"21":8,"22":2,"23":8,"24":4,"25":16,"26":4,"27":16,"28":4,"29":8,"30":4,"31":8,"32":4,"33":8,"34":4,"35":8,"36":2,"37":8,"38":2,"39":8,"40":2,"41":8,"42":4,"43":8,"44":4,"45":8,"46":8,"47":16,"48":8,"49":16,"50":8,"51":8,"52":8,"53":8,"54":6,"55":12,"56":6,"57":12,"58":6,"59":12,"60":24,"61":48,"62":6,"63":12,"64":2,"65":2,"66":2,"67":2,"68":4,"69":2,"70":1,"71":2,"72":2,"73":2},"criticality":{"1":"low","2":"high","3":"low","4":"high","5":"low","6":"high","7":"low","8":"high","9":"low","10":"high","11":"low","12":"high","13":"low","14":"high","15":"low","16":"high","17":"med","18":"low","19":"high","20":"low","21":"high","22":"low","23":"high","24":"low","25":"high","26":"low","27":"high","28":"med","29":"high","30":"med","31":"high","32":"med","33":"high","34":"med","35":"high","36":"low","37":"high","38":"low","39":"high","40":"low","41":"high","42":"med","43":"high","44":"med","45":"high","46":"low","47":"med","48":"low","49":"med","50":"med","51":"med","52":"med","53":"med","54":"med","55":"high","56":"med","57":"high","58":"med","59":"high","60":"med","61":"high","62":"med","63":"high","64":"high","65":"high","66":"high","67":"high","68":"high","69":"high","70":"high","71":"high","72":"high","73":"med"},"start_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"end_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"mute_alert":{"1":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","2":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","3":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","4":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":"zone_office_pump_hot_water_enable_sensor","18":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","19":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","20":null,"21":null,"22":null,"23":null,"24":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","25":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","26":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","27":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","28":null,"29":null,"30":"ahu_102_air_return_temp_sensor","31":"ahu_102_air_return_temp_sensor","32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":"ahu_23_enable_sched","55":"ahu_23_enable_sched","56":null,"57":null,"58":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","59":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","60":null,"61":null,"62":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","63":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","64":null,"65":null,"66":null,"67":null,"68":"ahu_102_air_return_temp_sensor, ahu_231_air_return_temp_sensor","69":null,"70":null,"71":null,"72":null,"73":null},"mute_logs":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":"all","45":"all","46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":"dewPoint,wetBulb","59":"dewPoint,wetBulb","60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"qa":{"1":"hvac_qa","2":"hvac_qa","3":"hvac_qa","4":"hvac_qa","5":"hvac_qa","6":"hvac_qa","7":"hvac_qa","8":"hvac_qa","9":"hvac_qa","10":"hvac_qa","11":"hvac_qa","12":"hvac_qa","13":"hvac_qa","14":"hvac_qa","15":"hvac_qa","16":"hvac_qa","17":"hvac_qa","18":"hvac_qa","19":"hvac_qa","20":"hvac_qa","21":"hvac_qa","22":"hvac_qa","23":"hvac_qa","24":"hvac_qa","25":"hvac_qa","26":"hvac_qa","27":"hvac_qa","28":"hvac_qa","29":"hvac_qa","30":"hvac_qa","31":"hvac_qa","32":"hvac_qa","33":"hvac_qa","34":"hvac_qa","35":"hvac_qa","36":"hvac_qa","37":"hvac_qa","38":"hvac_qa","39":"hvac_qa","40":"hvac_qa","41":"hvac_qa","42":"hvac_qa","43":"hvac_qa","44":"hvac_qa","45":"hvac_qa","46":"hvac_qa","47":"hvac_qa","48":"hvac_qa","49":"hvac_qa","50":"hvac_qa","51":"hvac_qa","52":"hvac_qa","53":"hvac_qa","54":"data_qa","55":"data_qa","56":"data_qa","57":"data_qa","58":"data_qa","59":"data_qa","60":"data_qa","61":"data_qa","62":"data_qa","63":"data_qa","64":"hvac_qa","65":"hvac_qa","66":"hvac_qa","67":"hvac_qa","68":"hvac_qa","69":"hvac_qa","70":"hvac_qa","71":"hvac_qa","72":"hvac_qa","73":"hvac_qa"}},"logs_link":"https://colab.research.google.com/drive/16lMaXuYFvn-BCOy2ZuAUO8aYpUyEneEQ"}'
# qa_data = json.loads(json_data)
# subcollection_ref.add(qa_data, document_id='qa_config')

#json_data = '{"_comment_":"This is QA settings","settings":{"mute_rules":false,"station_id":"10567","country":"Germany","state":"TH"},"rules":{"rule_name":{"1":"ahu_cmd_enabled_24h","2":"ahu_cmd_enabled_72h","3":"ahu_enabled_24h","4":"ahu_enabled_72h","5":"chiller_enabled_24h","6":"chiller_enabled_72h","7":"chilled_water_pump_enabled_24h","8":"chilled_water_pump_enabled_72h","9":"condenser_water_pump_enabled_24h","10":"condenser_water_pump_enabled_72h","11":"coolingTower_enabled_24h","12":"coolingTower_enabled_72h","13":"boiler_enabled_24h","14":"boiler_enabled_72h","15":"heat_pump_enabled_24h","16":"heat_pump_enabled_72h","17":"hot_water_pump_enabled_72h","18":"air_flow_>75perc_4h","19":"air_flow_>75perc_8h","20":"chilled_hot_water_valve_>50perc_1h","21":"chilled_hot_water_valve_>50perc_4h","22":"hot_water_valve_not_closing_1h","23":"hot_water_valve_not_closing_4h","24":"hot_water_valve_>90perc_2h","25":"hot_water_valve_>90perc_8h","26":"chilled_water_valve_>90perc_2h","27":"chilled_water_valve_>90perc_8h","28":"zone_air_temp_>28C_2h","29":"zone_air_temp_>28C_4h","30":"zone_air_temp_<15C_2h","31":"zone_air_temp_<15C_4h","32":"discharge_air_temp_>40C_2h","33":"discharge_air_temp_>40C_4h","34":"discharge_air_temp_<10C_2h","35":"discharge_air_temp_<10C_4h","36":"chilled_water_valve_not_closing_1h","37":"chilled_water_valve_not_closing_4h","38":"chilled_water_valve_not_opening_1h","39":"chilled_water_valve_not_opening_4h","40":"hot_water_valve_not_opening_1h","41":"hot_water_valve_not_opening_4h","42":"water_almost_boiling_2h","43":"water_almost_boiling_4h","44":"water_almost_freezing_2h","45":"water_almost_freezing_4h","46":"pump_speed_>90perc_4h","47":"pump_speed_>90perc_8h","48":"fan_speed_>90perc_4h","49":"fan_speed_>90perc_8h","50":"constant_ahu_air_discharge_temp_sp","51":"constant_hot_water_temp_sp","52":"constant_chilled_water_temp_sp","53":"constant_ahu_air_flow_sp","54":"missing_values_3h","55":"missing_values_6h","56":"temp_sensor_<-40_3h","57":"temp_sensor_<-40_6h","58":"negative_values_3h","59":"negative_values_6h","60":"constant_values_24h","61":"constant_values_48h","62":"temp_sensor_>100_3h","63":"temp_sensor_>100_6h","64":"zone_office_hot_water_temp_low_1h","65":"heat_exchanger_1_hot_water_temp_low_1h","66":"heat_exchanger_2_hot_water_temp_low_1h","67":"heat_exchanger_pump_pressure_<0.45bar_1h","68":"ahu_air_return_temp_<16C_2h","69":"zone_office_pump_enable_sensor_OFF_1h","70":"zone_office_hot_water_alarm_ON_30m","71":"zone_office_water_valve_sp_>95perc_1h","72":"kaufland_air_discharge_temp<15C_1h","73":"customer_center_hot_water_temp_low_1h"},"alias_a":{"1":"ahu_enable_cmd","2":"ahu_enable_cmd","3":"ahu_enable_sensor","4":"ahu_enable_sensor","5":"chiller_enable_sensor","6":"chiller_enable_sensor","7":"chilled_water_pump_enable_sensor","8":"chilled_water_pump_enable_sensor","9":"condenser_water_pump_enable_sensor","10":"condenser_water_pump_enable_sensor","11":"coolingTower_enable_sensor","12":"coolingTower_enable_sensor","13":"boiler_enable_sensor","14":"boiler_enable_sensor","15":"heatPump_enable_sensor","16":"heatPump_enable_sensor","17":"hot_water_enable_sensor","18":"air_flow_sp","19":"air_flow_sp","20":"ahu_chilled_water_valve_sp","21":"ahu_chilled_water_valve_sp","22":"ahu_discharge_air_temp_sensor","23":"ahu_discharge_air_temp_sensor","24":"ahu_hot_water_valve_sp","25":"ahu_hot_water_valve_sp","26":"ahu_chilled_water_valve_sp","27":"ahu_chilled_water_valve_sp","28":"zone_air_return_temp_sensor","29":"zone_air_return_temp_sensor","30":"zone_air_return_temp_sensor","31":"zone_air_return_temp_sensor","32":"ahu_discharge_air_temp_sensor","33":"ahu_discharge_air_temp_sensor","34":"ahu_discharge_air_temp_sensor","35":"ahu_discharge_air_temp_sensor","36":"ahu_discharge_air_temp_sensor","37":"ahu_discharge_air_temp_sensor","38":"ahu_discharge_air_temp_sensor","39":"ahu_discharge_air_temp_sensor","40":"ahu_discharge_air_temp_sensor","41":"ahu_discharge_air_temp_sensor","42":"water_temp_sensor","43":"water_temp_sensor","44":"water_temp_sensor","45":"water_temp_sensor","46":"water_flow_sp","47":"water_flow_sp","48":"air_flow_sp","49":"air_flow_sp","50":"ahu_air_discharge_temp_sp","51":"hot_water_temp_sp","52":"chilled_water_temp_sp","53":"air_flow_sp","54":null,"55":null,"56":"temp_sensor","57":"temp_sensor","58":"-temp","59":"-temp","60":"temp_sensor","61":"temp_sensor","62":"temp_sensor","63":"temp_sensor","64":"zone_office_hot_water_entering_temp_sensor","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sensor","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sensor","67":"heatExchanger_pump_hot_water_delta_pressure_sensor","68":"ahu_air_return_temp_sensor","69":"zone_office_pump_hot_water_enable_sensor","70":"zone_office_pump_hot_water_alarm","71":"zone_office_hot_water_valve_sp","72":"ahu_212_air_discharge_temp_sensor","73":"zone_7_heatExchanger_2_hot_water_entering_temp_sensor"},"alias_b":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_hot_water_valve_sp","21":"ahu_hot_water_valve_sp","22":"ahu_hot_water_valve_sp","23":"ahu_hot_water_valve_sp","24":"ahu_fan_air_return_enable_cmd","25":"ahu_fan_air_return_enable_cmd","26":"ahu_fan_air_return_enable_cmd","27":"ahu_fan_air_return_enable_cmd","28":"ahu_fan_air_return_enable_cmd","29":"ahu_fan_air_return_enable_cmd","30":"ahu_fan_air_return_enable_cmd","31":"ahu_fan_air_return_enable_cmd","32":"ahu_fan_air_discharge_enable_cmd","33":"ahu_fan_air_discharge_enable_cmd","34":"ahu_fan_air_discharge_enable_cmd","35":"ahu_fan_air_discharge_enable_cmd","36":"ahu_chilled_water_valve_sp","37":"ahu_chilled_water_valve_sp","38":"ahu_chilled_water_valve_sp","39":"ahu_chilled_water_valve_sp","40":"ahu_hot_water_valve_sp","41":"ahu_hot_water_valve_sp","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"zone_office_hot_water_entering_temp_sp","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sp","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sp","67":"heatExchanger_pump_hot_water_enable_cmd","68":"ahu_fan_air_return_enable_cmd","69":null,"70":null,"71":"heatExchanger_pump_hot_water_enable_cmd ","72":null,"73":"zone_7_heatExchanger_2_hot_water_entering_temp_sp"},"alias_c":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_enable_sensor","21":"ahu_enable_sensor","22":"ahu_enable_sensor","23":"ahu_enable_sensor","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"ahu_enable_sensor","37":"ahu_enable_sensor","38":"ahu_enable_sensor","39":"ahu_enable_sensor","40":"ahu_enable_sensor","41":"ahu_enable_sensor","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_1_primaryLoop_hot_water_valve_sp","65":"heatExchanger_1_primaryLoop_hot_water_valve_sp","66":"heatExchanger_1_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_1_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_1_primaryLoop_hot_water_valve_sp"},"alias_d":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":"outside_air_temp","23":"outside_air_temp","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"outside_air_temp","37":"outside_air_temp","38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_2_primaryLoop_hot_water_valve_sp","65":"heatExchanger_2_primaryLoop_hot_water_valve_sp","66":"heatExchanger_2_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_2_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_2_primaryLoop_hot_water_valve_sp"},"equation_1":{"1":"alias_a > 0","2":"alias_a > 0","3":"alias_a > 0","4":"alias_a > 0","5":"alias_a > 0","6":"alias_a > 0","7":"alias_a > 0","8":"alias_a > 0","9":"alias_a > 0","10":"alias_a > 0","11":"alias_a > 0","12":"alias_a > 0","13":"alias_a > 0","14":"alias_a > 0","15":"alias_a > 0","16":"alias_a > 0","17":"alias_a > 0","18":"alias_a > 75","19":"alias_a > 75","20":"alias_a > 50 and alias_b > 50 and alias_c == 1","21":"alias_a > 50 and alias_b > 50 and alias_c == 1","22":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","23":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","24":"alias_a > 90 and alias_b ==1","25":"alias_a > 90 and alias_b ==1","26":"alias_a > 90 and alias_b ==1","27":"alias_a > 90 and alias_b ==1","28":"alias_a > 28 and alias_b ==1","29":"alias_a > 28 and alias_b ==1","30":"alias_a < 15 and alias_b == 1","31":"alias_a < 15 and alias_b == 1","32":"alias_a > 40 and alias_b == 1","33":"alias_a > 40 and alias_b == 1","34":"alias_a < 10 and alias_b ==1 ","35":"alias_a < 10 and alias_b ==1 ","36":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","37":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","38":"alias_a > 20 and alias_b > 90 and alias_c ==1","39":"alias_a > 20 and alias_b > 90 and alias_c ==2","40":"alias_a < 20 and alias_b > 90 and alias_c ==1","41":"alias_a < 20 and alias_b > 90 and alias_c ==1","42":"alias_a > 90","43":"alias_a > 90","44":"alias_a < 5","45":"alias_a < 5","46":"alias_a >= 90","47":"alias_a >= 90","48":"alias_a >= 90","49":"alias_a >= 90","50":null,"51":null,"52":null,"53":null,"54":"pd.isna(alias_a)","55":"pd.isna(alias_a)","56":"alias_a < -40","57":"alias_a < -40","58":"alias_a < 0","59":"alias_a < 0","60":null,"61":null,"62":"alias_a > 100","63":"alias_a > 100","64":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4","65":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","66":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","67":"alias_a < 0.45 and alias_b ==1","68":"alias_a < 16 and alias_b==1","69":"alias_a==0","70":"alias_a != 1","71":"alias_a>95 and alias_b == 1 and (alias_c > 10 or alias_d > 10)","72":"alias_a<15","73":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4"},"equation_2":{"1":"streak >= 24","2":"streak >= 72","3":"streak >= 24","4":"streak >= 72","5":"streak >= 24","6":"streak >= 72","7":"streak >= 24","8":"streak >= 72","9":"streak >= 24","10":"streak >= 72","11":"streak >= 24","12":"streak >= 72","13":"streak >= 24","14":"streak >= 72","15":"streak >= 24","16":"streak >= 72","17":"streak >= 72","18":"streak >= 4","19":"streak >= 8","20":"streak >= 1","21":"streak >= 4","22":"streak >= 1","23":"streak >= 4","24":"streak >= 2","25":"streak >= 8","26":"streak >= 2","27":"streak >= 8","28":"streak >= 2","29":"streak >= 4","30":"streak >= 2","31":"streak >= 4","32":"streak >= 2","33":"streak >= 4","34":"streak >= 2","35":"streak >= 4","36":"streak >= 1","37":"streak >= 4","38":"streak >= 1","39":"streak >= 4","40":"streak >= 1","41":"streak >= 4","42":"streak >= 2","43":"streak >= 4","44":"streak >= 2","45":"streak >= 4","46":"streak >= 4","47":"streak >= 8","48":"streak >= 4","49":"streak >= 8","50":"std == 0","51":"std == 0","52":"std == 0","53":"std == 0","54":"streak >= 3","55":"streak >= 6","56":"streak >= 3","57":"streak >= 6","58":"streak >= 3","59":"streak >= 6","60":"std == 0","61":"std == 0","62":"streak >= 3","63":"streak >= 6","64":"streak >= 1","65":"streak >= 1","66":"streak >= 1","67":"streak >= 1","68":"streak >= 2","69":"streak >= 1","70":"streak >= 0.5","71":"streak >= 1","72":"streak >= 1","73":"streak >= 1"},"duration_hours":{"1":24,"2":72,"3":24,"4":72,"5":24,"6":72,"7":24,"8":72,"9":24,"10":72,"11":24,"12":72,"13":24,"14":72,"15":24,"16":72,"17":72,"18":8,"19":16,"20":2,"21":8,"22":2,"23":8,"24":4,"25":16,"26":4,"27":16,"28":4,"29":8,"30":4,"31":8,"32":4,"33":8,"34":4,"35":8,"36":2,"37":8,"38":2,"39":8,"40":2,"41":8,"42":4,"43":8,"44":4,"45":8,"46":8,"47":16,"48":8,"49":16,"50":8,"51":8,"52":8,"53":8,"54":6,"55":12,"56":6,"57":12,"58":6,"59":12,"60":24,"61":48,"62":6,"63":12,"64":2,"65":2,"66":2,"67":2,"68":4,"69":2,"70":1,"71":2,"72":2,"73":2},"criticality":{"1":"low","2":"high","3":"low","4":"high","5":"low","6":"high","7":"low","8":"high","9":"low","10":"high","11":"low","12":"high","13":"low","14":"high","15":"low","16":"high","17":"med","18":"low","19":"high","20":"low","21":"high","22":"low","23":"high","24":"low","25":"high","26":"low","27":"high","28":"med","29":"high","30":"med","31":"high","32":"med","33":"high","34":"med","35":"high","36":"low","37":"high","38":"low","39":"high","40":"low","41":"high","42":"med","43":"high","44":"med","45":"high","46":"low","47":"med","48":"low","49":"med","50":"med","51":"med","52":"med","53":"med","54":"med","55":"high","56":"med","57":"high","58":"med","59":"high","60":"med","61":"high","62":"med","63":"high","64":"high","65":"high","66":"high","67":"high","68":"high","69":"high","70":"high","71":"high","72":"high","73":"med"},"start_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"end_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"mute_alert":{"1":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","2":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","3":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","4":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":"zone_office_pump_hot_water_enable_sensor","18":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","19":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","20":null,"21":null,"22":null,"23":null,"24":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","25":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","26":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","27":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","28":null,"29":null,"30":"ahu_102_air_return_temp_sensor","31":"ahu_102_air_return_temp_sensor","32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":"ahu_23_enable_sched","55":"ahu_23_enable_sched","56":null,"57":null,"58":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","59":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","60":null,"61":null,"62":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","63":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","64":null,"65":null,"66":null,"67":null,"68":"ahu_102_air_return_temp_sensor, ahu_231_air_return_temp_sensor","69":null,"70":null,"71":null,"72":null,"73":null},"mute_logs":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":"all","45":"all","46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":"dewPoint,wetBulb","59":"dewPoint,wetBulb","60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"qa":{"1":"hvac_qa","2":"hvac_qa","3":"hvac_qa","4":"hvac_qa","5":"hvac_qa","6":"hvac_qa","7":"hvac_qa","8":"hvac_qa","9":"hvac_qa","10":"hvac_qa","11":"hvac_qa","12":"hvac_qa","13":"hvac_qa","14":"hvac_qa","15":"hvac_qa","16":"hvac_qa","17":"hvac_qa","18":"hvac_qa","19":"hvac_qa","20":"hvac_qa","21":"hvac_qa","22":"hvac_qa","23":"hvac_qa","24":"hvac_qa","25":"hvac_qa","26":"hvac_qa","27":"hvac_qa","28":"hvac_qa","29":"hvac_qa","30":"hvac_qa","31":"hvac_qa","32":"hvac_qa","33":"hvac_qa","34":"hvac_qa","35":"hvac_qa","36":"hvac_qa","37":"hvac_qa","38":"hvac_qa","39":"hvac_qa","40":"hvac_qa","41":"hvac_qa","42":"hvac_qa","43":"hvac_qa","44":"hvac_qa","45":"hvac_qa","46":"hvac_qa","47":"hvac_qa","48":"hvac_qa","49":"hvac_qa","50":"hvac_qa","51":"hvac_qa","52":"hvac_qa","53":"hvac_qa","54":"data_qa","55":"data_qa","56":"data_qa","57":"data_qa","58":"data_qa","59":"data_qa","60":"data_qa","61":"data_qa","62":"data_qa","63":"data_qa","64":"hvac_qa","65":"hvac_qa","66":"hvac_qa","67":"hvac_qa","68":"hvac_qa","69":"hvac_qa","70":"hvac_qa","71":"hvac_qa","72":"hvac_qa","73":"hvac_qa"}},"logs_link":"https://colab.research.google.com/drive/16lMaXuYFvn-BCOy2ZuAUO8aYpUyEneEQ"}'
json_data = '{"field1": "value1", "field2": "value2"}'
# data1 = json.loads(json_data)
# subcollection_ref.add(data1, document_id='test2')

# %%
#from google.cloud import firestore
import json

# Initialize Firestore Client
# db = firestore.Client()

# Get a reference to the sub-collection
# subcollection_ref = db.collection('clients_config').document('gera-arcaden-germany').collection('sub_configs')
#json_data  = '{"_comment_":"This is QA settings","settings":{"mute_rules":false,"station_id":"10567","country":"Germany","state":"TH"},"rules":{"rule_name":{"1":"ahu_cmd_enabled_24h","2":"ahu_cmd_enabled_72h","3":"ahu_enabled_24h","4":"ahu_enabled_72h","5":"chiller_enabled_24h","6":"chiller_enabled_72h","7":"chilled_water_pump_enabled_24h","8":"chilled_water_pump_enabled_72h","9":"condenser_water_pump_enabled_24h","10":"condenser_water_pump_enabled_72h","11":"coolingTower_enabled_24h","12":"coolingTower_enabled_72h","13":"boiler_enabled_24h","14":"boiler_enabled_72h","15":"heat_pump_enabled_24h","16":"heat_pump_enabled_72h","17":"hot_water_pump_enabled_72h","18":"air_flow_>75perc_4h","19":"air_flow_>75perc_8h","20":"chilled_hot_water_valve_>50perc_1h","21":"chilled_hot_water_valve_>50perc_4h","22":"hot_water_valve_not_closing_1h","23":"hot_water_valve_not_closing_4h","24":"hot_water_valve_>90perc_2h","25":"hot_water_valve_>90perc_8h","26":"chilled_water_valve_>90perc_2h","27":"chilled_water_valve_>90perc_8h","28":"zone_air_temp_>28C_2h","29":"zone_air_temp_>28C_4h","30":"zone_air_temp_<15C_2h","31":"zone_air_temp_<15C_4h","32":"discharge_air_temp_>40C_2h","33":"discharge_air_temp_>40C_4h","34":"discharge_air_temp_<10C_2h","35":"discharge_air_temp_<10C_4h","36":"chilled_water_valve_not_closing_1h","37":"chilled_water_valve_not_closing_4h","38":"chilled_water_valve_not_opening_1h","39":"chilled_water_valve_not_opening_4h","40":"hot_water_valve_not_opening_1h","41":"hot_water_valve_not_opening_4h","42":"water_almost_boiling_2h","43":"water_almost_boiling_4h","44":"water_almost_freezing_2h","45":"water_almost_freezing_4h","46":"pump_speed_>90perc_4h","47":"pump_speed_>90perc_8h","48":"fan_speed_>90perc_4h","49":"fan_speed_>90perc_8h","50":"constant_ahu_air_discharge_temp_sp","51":"constant_hot_water_temp_sp","52":"constant_chilled_water_temp_sp","53":"constant_ahu_air_flow_sp","54":"missing_values_3h","55":"missing_values_6h","56":"temp_sensor_<-40_3h","57":"temp_sensor_<-40_6h","58":"negative_values_3h","59":"negative_values_6h","60":"constant_values_24h","61":"constant_values_48h","62":"temp_sensor_>100_3h","63":"temp_sensor_>100_6h","64":"zone_office_hot_water_temp_low_1h","65":"heat_exchanger_1_hot_water_temp_low_1h","66":"heat_exchanger_2_hot_water_temp_low_1h","67":"heat_exchanger_pump_pressure_<0.45bar_1h","68":"ahu_air_return_temp_<16C_2h","69":"zone_office_pump_enable_sensor_OFF_1h","70":"zone_office_hot_water_alarm_ON_30m","71":"zone_office_water_valve_sp_>95perc_1h","72":"kaufland_air_discharge_temp<15C_1h","73":"customer_center_hot_water_temp_low_1h"},"alias_a":{"1":"ahu_enable_cmd","2":"ahu_enable_cmd","3":"ahu_enable_sensor","4":"ahu_enable_sensor","5":"chiller_enable_sensor","6":"chiller_enable_sensor","7":"chilled_water_pump_enable_sensor","8":"chilled_water_pump_enable_sensor","9":"condenser_water_pump_enable_sensor","10":"condenser_water_pump_enable_sensor","11":"coolingTower_enable_sensor","12":"coolingTower_enable_sensor","13":"boiler_enable_sensor","14":"boiler_enable_sensor","15":"heatPump_enable_sensor","16":"heatPump_enable_sensor","17":"hot_water_enable_sensor","18":"air_flow_sp","19":"air_flow_sp","20":"ahu_chilled_water_valve_sp","21":"ahu_chilled_water_valve_sp","22":"ahu_discharge_air_temp_sensor","23":"ahu_discharge_air_temp_sensor","24":"ahu_hot_water_valve_sp","25":"ahu_hot_water_valve_sp","26":"ahu_chilled_water_valve_sp","27":"ahu_chilled_water_valve_sp","28":"zone_air_return_temp_sensor","29":"zone_air_return_temp_sensor","30":"zone_air_return_temp_sensor","31":"zone_air_return_temp_sensor","32":"ahu_discharge_air_temp_sensor","33":"ahu_discharge_air_temp_sensor","34":"ahu_discharge_air_temp_sensor","35":"ahu_discharge_air_temp_sensor","36":"ahu_discharge_air_temp_sensor","37":"ahu_discharge_air_temp_sensor","38":"ahu_discharge_air_temp_sensor","39":"ahu_discharge_air_temp_sensor","40":"ahu_discharge_air_temp_sensor","41":"ahu_discharge_air_temp_sensor","42":"water_temp_sensor","43":"water_temp_sensor","44":"water_temp_sensor","45":"water_temp_sensor","46":"water_flow_sp","47":"water_flow_sp","48":"air_flow_sp","49":"air_flow_sp","50":"ahu_air_discharge_temp_sp","51":"hot_water_temp_sp","52":"chilled_water_temp_sp","53":"air_flow_sp","54":null,"55":null,"56":"temp_sensor","57":"temp_sensor","58":"-temp","59":"-temp","60":"temp_sensor","61":"temp_sensor","62":"temp_sensor","63":"temp_sensor","64":"zone_office_hot_water_entering_temp_sensor","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sensor","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sensor","67":"heatExchanger_pump_hot_water_delta_pressure_sensor","68":"ahu_air_return_temp_sensor","69":"zone_office_pump_hot_water_enable_sensor","70":"zone_office_pump_hot_water_alarm","71":"zone_office_hot_water_valve_sp","72":"ahu_212_air_discharge_temp_sensor","73":"zone_7_heatExchanger_2_hot_water_entering_temp_sensor"},"alias_b":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_hot_water_valve_sp","21":"ahu_hot_water_valve_sp","22":"ahu_hot_water_valve_sp","23":"ahu_hot_water_valve_sp","24":"ahu_fan_air_return_enable_cmd","25":"ahu_fan_air_return_enable_cmd","26":"ahu_fan_air_return_enable_cmd","27":"ahu_fan_air_return_enable_cmd","28":"ahu_fan_air_return_enable_cmd","29":"ahu_fan_air_return_enable_cmd","30":"ahu_fan_air_return_enable_cmd","31":"ahu_fan_air_return_enable_cmd","32":"ahu_fan_air_discharge_enable_cmd","33":"ahu_fan_air_discharge_enable_cmd","34":"ahu_fan_air_discharge_enable_cmd","35":"ahu_fan_air_discharge_enable_cmd","36":"ahu_chilled_water_valve_sp","37":"ahu_chilled_water_valve_sp","38":"ahu_chilled_water_valve_sp","39":"ahu_chilled_water_valve_sp","40":"ahu_hot_water_valve_sp","41":"ahu_hot_water_valve_sp","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"zone_office_hot_water_entering_temp_sp","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sp","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sp","67":"heatExchanger_pump_hot_water_enable_cmd","68":"ahu_fan_air_return_enable_cmd","69":null,"70":null,"71":"heatExchanger_pump_hot_water_enable_cmd ","72":null,"73":"zone_7_heatExchanger_2_hot_water_entering_temp_sp"},"alias_c":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_enable_sensor","21":"ahu_enable_sensor","22":"ahu_enable_sensor","23":"ahu_enable_sensor","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"ahu_enable_sensor","37":"ahu_enable_sensor","38":"ahu_enable_sensor","39":"ahu_enable_sensor","40":"ahu_enable_sensor","41":"ahu_enable_sensor","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_1_primaryLoop_hot_water_valve_sp","65":"heatExchanger_1_primaryLoop_hot_water_valve_sp","66":"heatExchanger_1_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_1_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_1_primaryLoop_hot_water_valve_sp"},"alias_d":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":"outside_air_temp","23":"outside_air_temp","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"outside_air_temp","37":"outside_air_temp","38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_2_primaryLoop_hot_water_valve_sp","65":"heatExchanger_2_primaryLoop_hot_water_valve_sp","66":"heatExchanger_2_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_2_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_2_primaryLoop_hot_water_valve_sp"},"equation_1":{"1":"alias_a > 0","2":"alias_a > 0","3":"alias_a > 0","4":"alias_a > 0","5":"alias_a > 0","6":"alias_a > 0","7":"alias_a > 0","8":"alias_a > 0","9":"alias_a > 0","10":"alias_a > 0","11":"alias_a > 0","12":"alias_a > 0","13":"alias_a > 0","14":"alias_a > 0","15":"alias_a > 0","16":"alias_a > 0","17":"alias_a > 0","18":"alias_a > 75","19":"alias_a > 75","20":"alias_a > 50 and alias_b > 50 and alias_c == 1","21":"alias_a > 50 and alias_b > 50 and alias_c == 1","22":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","23":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","24":"alias_a > 90 and alias_b ==1","25":"alias_a > 90 and alias_b ==1","26":"alias_a > 90 and alias_b ==1","27":"alias_a > 90 and alias_b ==1","28":"alias_a > 28 and alias_b ==1","29":"alias_a > 28 and alias_b ==1","30":"alias_a < 15 and alias_b == 1","31":"alias_a < 15 and alias_b == 1","32":"alias_a > 40 and alias_b == 1","33":"alias_a > 40 and alias_b == 1","34":"alias_a < 10 and alias_b ==1 ","35":"alias_a < 10 and alias_b ==1 ","36":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","37":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","38":"alias_a > 20 and alias_b > 90 and alias_c ==1","39":"alias_a > 20 and alias_b > 90 and alias_c ==2","40":"alias_a < 20 and alias_b > 90 and alias_c ==1","41":"alias_a < 20 and alias_b > 90 and alias_c ==1","42":"alias_a > 90","43":"alias_a > 90","44":"alias_a < 5","45":"alias_a < 5","46":"alias_a >= 90","47":"alias_a >= 90","48":"alias_a >= 90","49":"alias_a >= 90","50":null,"51":null,"52":null,"53":null,"54":"pd.isna(alias_a)","55":"pd.isna(alias_a)","56":"alias_a < -40","57":"alias_a < -40","58":"alias_a < 0","59":"alias_a < 0","60":null,"61":null,"62":"alias_a > 100","63":"alias_a > 100","64":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4","65":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","66":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","67":"alias_a < 0.45 and alias_b ==1","68":"alias_a < 16 and alias_b==1","69":"alias_a==0","70":"alias_a != 1","71":"alias_a>95 and alias_b == 1 and (alias_c > 10 or alias_d > 10)","72":"alias_a<15","73":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4"},"equation_2":{"1":"streak >= 24","2":"streak >= 72","3":"streak >= 24","4":"streak >= 72","5":"streak >= 24","6":"streak >= 72","7":"streak >= 24","8":"streak >= 72","9":"streak >= 24","10":"streak >= 72","11":"streak >= 24","12":"streak >= 72","13":"streak >= 24","14":"streak >= 72","15":"streak >= 24","16":"streak >= 72","17":"streak >= 72","18":"streak >= 4","19":"streak >= 8","20":"streak >= 1","21":"streak >= 4","22":"streak >= 1","23":"streak >= 4","24":"streak >= 2","25":"streak >= 8","26":"streak >= 2","27":"streak >= 8","28":"streak >= 2","29":"streak >= 4","30":"streak >= 2","31":"streak >= 4","32":"streak >= 2","33":"streak >= 4","34":"streak >= 2","35":"streak >= 4","36":"streak >= 1","37":"streak >= 4","38":"streak >= 1","39":"streak >= 4","40":"streak >= 1","41":"streak >= 4","42":"streak >= 2","43":"streak >= 4","44":"streak >= 2","45":"streak >= 4","46":"streak >= 4","47":"streak >= 8","48":"streak >= 4","49":"streak >= 8","50":"std == 0","51":"std == 0","52":"std == 0","53":"std == 0","54":"streak >= 3","55":"streak >= 6","56":"streak >= 3","57":"streak >= 6","58":"streak >= 3","59":"streak >= 6","60":"std == 0","61":"std == 0","62":"streak >= 3","63":"streak >= 6","64":"streak >= 1","65":"streak >= 1","66":"streak >= 1","67":"streak >= 1","68":"streak >= 2","69":"streak >= 1","70":"streak >= 0.5","71":"streak >= 1","72":"streak >= 1","73":"streak >= 1"},"duration_hours":{"1":24,"2":72,"3":24,"4":72,"5":24,"6":72,"7":24,"8":72,"9":24,"10":72,"11":24,"12":72,"13":24,"14":72,"15":24,"16":72,"17":72,"18":8,"19":16,"20":2,"21":8,"22":2,"23":8,"24":4,"25":16,"26":4,"27":16,"28":4,"29":8,"30":4,"31":8,"32":4,"33":8,"34":4,"35":8,"36":2,"37":8,"38":2,"39":8,"40":2,"41":8,"42":4,"43":8,"44":4,"45":8,"46":8,"47":16,"48":8,"49":16,"50":8,"51":8,"52":8,"53":8,"54":6,"55":12,"56":6,"57":12,"58":6,"59":12,"60":24,"61":48,"62":6,"63":12,"64":2,"65":2,"66":2,"67":2,"68":4,"69":2,"70":1,"71":2,"72":2,"73":2},"criticality":{"1":"low","2":"high","3":"low","4":"high","5":"low","6":"high","7":"low","8":"high","9":"low","10":"high","11":"low","12":"high","13":"low","14":"high","15":"low","16":"high","17":"med","18":"low","19":"high","20":"low","21":"high","22":"low","23":"high","24":"low","25":"high","26":"low","27":"high","28":"med","29":"high","30":"med","31":"high","32":"med","33":"high","34":"med","35":"high","36":"low","37":"high","38":"low","39":"high","40":"low","41":"high","42":"med","43":"high","44":"med","45":"high","46":"low","47":"med","48":"low","49":"med","50":"med","51":"med","52":"med","53":"med","54":"med","55":"high","56":"med","57":"high","58":"med","59":"high","60":"med","61":"high","62":"med","63":"high","64":"high","65":"high","66":"high","67":"high","68":"high","69":"high","70":"high","71":"high","72":"high","73":"med"},"start_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"end_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"mute_alert":{"1":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","2":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","3":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","4":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":"zone_office_pump_hot_water_enable_sensor","18":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","19":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","20":null,"21":null,"22":null,"23":null,"24":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","25":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","26":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","27":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","28":null,"29":null,"30":"ahu_102_air_return_temp_sensor","31":"ahu_102_air_return_temp_sensor","32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":"ahu_23_enable_sched","55":"ahu_23_enable_sched","56":null,"57":null,"58":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","59":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","60":null,"61":null,"62":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","63":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","64":null,"65":null,"66":null,"67":null,"68":"ahu_102_air_return_temp_sensor, ahu_231_air_return_temp_sensor","69":null,"70":null,"71":null,"72":null,"73":null},"mute_logs":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":"all","45":"all","46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":"dewPoint,wetBulb","59":"dewPoint,wetBulb","60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"qa":{"1":"hvac_qa","2":"hvac_qa","3":"hvac_qa","4":"hvac_qa","5":"hvac_qa","6":"hvac_qa","7":"hvac_qa","8":"hvac_qa","9":"hvac_qa","10":"hvac_qa","11":"hvac_qa","12":"hvac_qa","13":"hvac_qa","14":"hvac_qa","15":"hvac_qa","16":"hvac_qa","17":"hvac_qa","18":"hvac_qa","19":"hvac_qa","20":"hvac_qa","21":"hvac_qa","22":"hvac_qa","23":"hvac_qa","24":"hvac_qa","25":"hvac_qa","26":"hvac_qa","27":"hvac_qa","28":"hvac_qa","29":"hvac_qa","30":"hvac_qa","31":"hvac_qa","32":"hvac_qa","33":"hvac_qa","34":"hvac_qa","35":"hvac_qa","36":"hvac_qa","37":"hvac_qa","38":"hvac_qa","39":"hvac_qa","40":"hvac_qa","41":"hvac_qa","42":"hvac_qa","43":"hvac_qa","44":"hvac_qa","45":"hvac_qa","46":"hvac_qa","47":"hvac_qa","48":"hvac_qa","49":"hvac_qa","50":"hvac_qa","51":"hvac_qa","52":"hvac_qa","53":"hvac_qa","54":"data_qa","55":"data_qa","56":"data_qa","57":"data_qa","58":"data_qa","59":"data_qa","60":"data_qa","61":"data_qa","62":"data_qa","63":"data_qa","64":"hvac_qa","65":"hvac_qa","66":"hvac_qa","67":"hvac_qa","68":"hvac_qa","69":"hvac_qa","70":"hvac_qa","71":"hvac_qa","72":"hvac_qa","73":"hvac_qa"}},"logs_link":"https://colab.research.google.com/drive/16lMaXuYFvn-BCOy2ZuAUO8aYpUyEneEQ"}'
#json_data = open('D:\gera_qa_config.json')

#json_data = '{"_comment_":"This is QA settings","settings":{"mute_rules":false,"station_id":"10567","country":"Germany","state":"TH"},"rules":{"rule_name":{"1":"ahu_cmd_enabled_24h","2":"ahu_cmd_enabled_72h","3":"ahu_enabled_24h","4":"ahu_enabled_72h","5":"chiller_enabled_24h","6":"chiller_enabled_72h","7":"chilled_water_pump_enabled_24h","8":"chilled_water_pump_enabled_72h","9":"condenser_water_pump_enabled_24h","10":"condenser_water_pump_enabled_72h","11":"coolingTower_enabled_24h","12":"coolingTower_enabled_72h","13":"boiler_enabled_24h","14":"boiler_enabled_72h","15":"heat_pump_enabled_24h","16":"heat_pump_enabled_72h","17":"hot_water_pump_enabled_72h","18":"air_flow_>75perc_4h","19":"air_flow_>75perc_8h","20":"chilled_hot_water_valve_>50perc_1h","21":"chilled_hot_water_valve_>50perc_4h","22":"hot_water_valve_not_closing_1h","23":"hot_water_valve_not_closing_4h","24":"hot_water_valve_>90perc_2h","25":"hot_water_valve_>90perc_8h","26":"chilled_water_valve_>90perc_2h","27":"chilled_water_valve_>90perc_8h","28":"zone_air_temp_>28C_2h","29":"zone_air_temp_>28C_4h","30":"zone_air_temp_<15C_2h","31":"zone_air_temp_<15C_4h","32":"discharge_air_temp_>40C_2h","33":"discharge_air_temp_>40C_4h","34":"discharge_air_temp_<10C_2h","35":"discharge_air_temp_<10C_4h","36":"chilled_water_valve_not_closing_1h","37":"chilled_water_valve_not_closing_4h","38":"chilled_water_valve_not_opening_1h","39":"chilled_water_valve_not_opening_4h","40":"hot_water_valve_not_opening_1h","41":"hot_water_valve_not_opening_4h","42":"water_almost_boiling_2h","43":"water_almost_boiling_4h","44":"water_almost_freezing_2h","45":"water_almost_freezing_4h","46":"pump_speed_>90perc_4h","47":"pump_speed_>90perc_8h","48":"fan_speed_>90perc_4h","49":"fan_speed_>90perc_8h","50":"constant_ahu_air_discharge_temp_sp","51":"constant_hot_water_temp_sp","52":"constant_chilled_water_temp_sp","53":"constant_ahu_air_flow_sp","54":"missing_values_3h","55":"missing_values_6h","56":"temp_sensor_<-40_3h","57":"temp_sensor_<-40_6h","58":"negative_values_3h","59":"negative_values_6h","60":"constant_values_24h","61":"constant_values_48h","62":"temp_sensor_>100_3h","63":"temp_sensor_>100_6h","64":"zone_office_hot_water_temp_low_1h","65":"heat_exchanger_1_hot_water_temp_low_1h","66":"heat_exchanger_2_hot_water_temp_low_1h","67":"heat_exchanger_pump_pressure_<0.45bar_1h","68":"ahu_air_return_temp_<16C_2h","69":"zone_office_pump_enable_sensor_OFF_1h","70":"zone_office_hot_water_alarm_ON_30m","71":"zone_office_water_valve_sp_>95perc_1h","72":"kaufland_air_discharge_temp<15C_1h","73":"customer_center_hot_water_temp_low_1h"},"alias_a":{"1":"ahu_enable_cmd","2":"ahu_enable_cmd","3":"ahu_enable_sensor","4":"ahu_enable_sensor","5":"chiller_enable_sensor","6":"chiller_enable_sensor","7":"chilled_water_pump_enable_sensor","8":"chilled_water_pump_enable_sensor","9":"condenser_water_pump_enable_sensor","10":"condenser_water_pump_enable_sensor","11":"coolingTower_enable_sensor","12":"coolingTower_enable_sensor","13":"boiler_enable_sensor","14":"boiler_enable_sensor","15":"heatPump_enable_sensor","16":"heatPump_enable_sensor","17":"hot_water_enable_sensor","18":"air_flow_sp","19":"air_flow_sp","20":"ahu_chilled_water_valve_sp","21":"ahu_chilled_water_valve_sp","22":"ahu_discharge_air_temp_sensor","23":"ahu_discharge_air_temp_sensor","24":"ahu_hot_water_valve_sp","25":"ahu_hot_water_valve_sp","26":"ahu_chilled_water_valve_sp","27":"ahu_chilled_water_valve_sp","28":"zone_air_return_temp_sensor","29":"zone_air_return_temp_sensor","30":"zone_air_return_temp_sensor","31":"zone_air_return_temp_sensor","32":"ahu_discharge_air_temp_sensor","33":"ahu_discharge_air_temp_sensor","34":"ahu_discharge_air_temp_sensor","35":"ahu_discharge_air_temp_sensor","36":"ahu_discharge_air_temp_sensor","37":"ahu_discharge_air_temp_sensor","38":"ahu_discharge_air_temp_sensor","39":"ahu_discharge_air_temp_sensor","40":"ahu_discharge_air_temp_sensor","41":"ahu_discharge_air_temp_sensor","42":"water_temp_sensor","43":"water_temp_sensor","44":"water_temp_sensor","45":"water_temp_sensor","46":"water_flow_sp","47":"water_flow_sp","48":"air_flow_sp","49":"air_flow_sp","50":"ahu_air_discharge_temp_sp","51":"hot_water_temp_sp","52":"chilled_water_temp_sp","53":"air_flow_sp","54":null,"55":null,"56":"temp_sensor","57":"temp_sensor","58":"-temp","59":"-temp","60":"temp_sensor","61":"temp_sensor","62":"temp_sensor","63":"temp_sensor","64":"zone_office_hot_water_entering_temp_sensor","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sensor","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sensor","67":"heatExchanger_pump_hot_water_delta_pressure_sensor","68":"ahu_air_return_temp_sensor","69":"zone_office_pump_hot_water_enable_sensor","70":"zone_office_pump_hot_water_alarm","71":"zone_office_hot_water_valve_sp","72":"ahu_212_air_discharge_temp_sensor","73":"zone_7_heatExchanger_2_hot_water_entering_temp_sensor"},"alias_b":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_hot_water_valve_sp","21":"ahu_hot_water_valve_sp","22":"ahu_hot_water_valve_sp","23":"ahu_hot_water_valve_sp","24":"ahu_fan_air_return_enable_cmd","25":"ahu_fan_air_return_enable_cmd","26":"ahu_fan_air_return_enable_cmd","27":"ahu_fan_air_return_enable_cmd","28":"ahu_fan_air_return_enable_cmd","29":"ahu_fan_air_return_enable_cmd","30":"ahu_fan_air_return_enable_cmd","31":"ahu_fan_air_return_enable_cmd","32":"ahu_fan_air_discharge_enable_cmd","33":"ahu_fan_air_discharge_enable_cmd","34":"ahu_fan_air_discharge_enable_cmd","35":"ahu_fan_air_discharge_enable_cmd","36":"ahu_chilled_water_valve_sp","37":"ahu_chilled_water_valve_sp","38":"ahu_chilled_water_valve_sp","39":"ahu_chilled_water_valve_sp","40":"ahu_hot_water_valve_sp","41":"ahu_hot_water_valve_sp","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"zone_office_hot_water_entering_temp_sp","65":"heatExchanger_1_secondaryLoop_hot_water_leaving_temp_sp","66":"heatExchanger_2_secondaryLoop_hot_water_leaving_temp_sp","67":"heatExchanger_pump_hot_water_enable_cmd","68":"ahu_fan_air_return_enable_cmd","69":null,"70":null,"71":"heatExchanger_pump_hot_water_enable_cmd ","72":null,"73":"zone_7_heatExchanger_2_hot_water_entering_temp_sp"},"alias_c":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":"ahu_enable_sensor","21":"ahu_enable_sensor","22":"ahu_enable_sensor","23":"ahu_enable_sensor","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"ahu_enable_sensor","37":"ahu_enable_sensor","38":"ahu_enable_sensor","39":"ahu_enable_sensor","40":"ahu_enable_sensor","41":"ahu_enable_sensor","42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_1_primaryLoop_hot_water_valve_sp","65":"heatExchanger_1_primaryLoop_hot_water_valve_sp","66":"heatExchanger_1_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_1_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_1_primaryLoop_hot_water_valve_sp"},"alias_d":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":"outside_air_temp","23":"outside_air_temp","24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":"outside_air_temp","37":"outside_air_temp","38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":"heatExchanger_2_primaryLoop_hot_water_valve_sp","65":"heatExchanger_2_primaryLoop_hot_water_valve_sp","66":"heatExchanger_2_primaryLoop_hot_water_valve_sp","67":null,"68":null,"69":null,"70":null,"71":"heatExchanger_2_primaryLoop_hot_water_valve_sp","72":null,"73":"heatExchanger_2_primaryLoop_hot_water_valve_sp"},"equation_1":{"1":"alias_a > 0","2":"alias_a > 0","3":"alias_a > 0","4":"alias_a > 0","5":"alias_a > 0","6":"alias_a > 0","7":"alias_a > 0","8":"alias_a > 0","9":"alias_a > 0","10":"alias_a > 0","11":"alias_a > 0","12":"alias_a > 0","13":"alias_a > 0","14":"alias_a > 0","15":"alias_a > 0","16":"alias_a > 0","17":"alias_a > 0","18":"alias_a > 75","19":"alias_a > 75","20":"alias_a > 50 and alias_b > 50 and alias_c == 1","21":"alias_a > 50 and alias_b > 50 and alias_c == 1","22":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","23":"alias_a >= 30 and alias_b == 0 and alias_c == 1 and alias_d < 30","24":"alias_a > 90 and alias_b ==1","25":"alias_a > 90 and alias_b ==1","26":"alias_a > 90 and alias_b ==1","27":"alias_a > 90 and alias_b ==1","28":"alias_a > 28 and alias_b ==1","29":"alias_a > 28 and alias_b ==1","30":"alias_a < 15 and alias_b == 1","31":"alias_a < 15 and alias_b == 1","32":"alias_a > 40 and alias_b == 1","33":"alias_a > 40 and alias_b == 1","34":"alias_a < 10 and alias_b ==1 ","35":"alias_a < 10 and alias_b ==1 ","36":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","37":"alias_a <= 15 and alias_b == 0 and alias_c == 1 and alias_d > 15","38":"alias_a > 20 and alias_b > 90 and alias_c ==1","39":"alias_a > 20 and alias_b > 90 and alias_c ==2","40":"alias_a < 20 and alias_b > 90 and alias_c ==1","41":"alias_a < 20 and alias_b > 90 and alias_c ==1","42":"alias_a > 90","43":"alias_a > 90","44":"alias_a < 5","45":"alias_a < 5","46":"alias_a >= 90","47":"alias_a >= 90","48":"alias_a >= 90","49":"alias_a >= 90","50":null,"51":null,"52":null,"53":null,"54":"pd.isna(alias_a)","55":"pd.isna(alias_a)","56":"alias_a < -40","57":"alias_a < -40","58":"alias_a < 0","59":"alias_a < 0","60":null,"61":null,"62":"alias_a > 100","63":"alias_a > 100","64":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4","65":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","66":"(alias_a < (alias_b -10)) and (alias_c > 10 or alias_d > 10)","67":"alias_a < 0.45 and alias_b ==1","68":"alias_a < 16 and alias_b==1","69":"alias_a==0","70":"alias_a != 1","71":"alias_a>95 and alias_b == 1 and (alias_c > 10 or alias_d > 10)","72":"alias_a<15","73":"(alias_a < (alias_b -10)) and  (alias_c > 10 or alias_d > 10) and hour >= 6 and hour <= 21 and day >= 0 and day <= 4"},"equation_2":{"1":"streak >= 24","2":"streak >= 72","3":"streak >= 24","4":"streak >= 72","5":"streak >= 24","6":"streak >= 72","7":"streak >= 24","8":"streak >= 72","9":"streak >= 24","10":"streak >= 72","11":"streak >= 24","12":"streak >= 72","13":"streak >= 24","14":"streak >= 72","15":"streak >= 24","16":"streak >= 72","17":"streak >= 72","18":"streak >= 4","19":"streak >= 8","20":"streak >= 1","21":"streak >= 4","22":"streak >= 1","23":"streak >= 4","24":"streak >= 2","25":"streak >= 8","26":"streak >= 2","27":"streak >= 8","28":"streak >= 2","29":"streak >= 4","30":"streak >= 2","31":"streak >= 4","32":"streak >= 2","33":"streak >= 4","34":"streak >= 2","35":"streak >= 4","36":"streak >= 1","37":"streak >= 4","38":"streak >= 1","39":"streak >= 4","40":"streak >= 1","41":"streak >= 4","42":"streak >= 2","43":"streak >= 4","44":"streak >= 2","45":"streak >= 4","46":"streak >= 4","47":"streak >= 8","48":"streak >= 4","49":"streak >= 8","50":"std == 0","51":"std == 0","52":"std == 0","53":"std == 0","54":"streak >= 3","55":"streak >= 6","56":"streak >= 3","57":"streak >= 6","58":"streak >= 3","59":"streak >= 6","60":"std == 0","61":"std == 0","62":"streak >= 3","63":"streak >= 6","64":"streak >= 1","65":"streak >= 1","66":"streak >= 1","67":"streak >= 1","68":"streak >= 2","69":"streak >= 1","70":"streak >= 0.5","71":"streak >= 1","72":"streak >= 1","73":"streak >= 1"},"duration_hours":{"1":24,"2":72,"3":24,"4":72,"5":24,"6":72,"7":24,"8":72,"9":24,"10":72,"11":24,"12":72,"13":24,"14":72,"15":24,"16":72,"17":72,"18":8,"19":16,"20":2,"21":8,"22":2,"23":8,"24":4,"25":16,"26":4,"27":16,"28":4,"29":8,"30":4,"31":8,"32":4,"33":8,"34":4,"35":8,"36":2,"37":8,"38":2,"39":8,"40":2,"41":8,"42":4,"43":8,"44":4,"45":8,"46":8,"47":16,"48":8,"49":16,"50":8,"51":8,"52":8,"53":8,"54":6,"55":12,"56":6,"57":12,"58":6,"59":12,"60":24,"61":48,"62":6,"63":12,"64":2,"65":2,"66":2,"67":2,"68":4,"69":2,"70":1,"71":2,"72":2,"73":2},"criticality":{"1":"low","2":"high","3":"low","4":"high","5":"low","6":"high","7":"low","8":"high","9":"low","10":"high","11":"low","12":"high","13":"low","14":"high","15":"low","16":"high","17":"med","18":"low","19":"high","20":"low","21":"high","22":"low","23":"high","24":"low","25":"high","26":"low","27":"high","28":"med","29":"high","30":"med","31":"high","32":"med","33":"high","34":"med","35":"high","36":"low","37":"high","38":"low","39":"high","40":"low","41":"high","42":"med","43":"high","44":"med","45":"high","46":"low","47":"med","48":"low","49":"med","50":"med","51":"med","52":"med","53":"med","54":"med","55":"high","56":"med","57":"high","58":"med","59":"high","60":"med","61":"high","62":"med","63":"high","64":"high","65":"high","66":"high","67":"high","68":"high","69":"high","70":"high","71":"high","72":"high","73":"med"},"start_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"end_date":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"mute_alert":{"1":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","2":"ahu_282_fan_air_return_enable_cmd, ahu_281_fan_air_return_enable_cmd,\nahu_212_fan_air_discharge_enable_cmd,ahu_212k_fan_air_return_enable_cmd ,\nahu_212w_fan_air_return_enable_cmd ,ahu_212k_fan_air_return_enable_sensor ,\nahu_212w_fan_air_return_enable_sensor , ahu_212_fan_air_discharge_enable_sensor ","3":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","4":"ahu_212_fan_air_discharge_enable_sensor,ahu_212k_fan_air_return_enable_sensor,ahu_212w_fan_air_return_enable_sensor","5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":"zone_office_pump_hot_water_enable_sensor","18":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","19":"ahu_5_air_discharge_flow_sp, ahu_5_air_return_flow_sp, ahu_7_air_discharge_flow_sp, ahu_7_air_return_flow_sp,ahu_231_air_discharge_flow_sp,ahu_231_air_return_flow_sp,ahu_102_air_discharge_flow_sp,ahu_102_air_return_flow_sp","20":null,"21":null,"22":null,"23":null,"24":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","25":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp, ahu_101_hot_water_valve_sp","26":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","27":"ahu_3_heatRecovery_water_valve_sp, ahu_6_heatRecovery_water_valve_sp, ahu_2_heatRecovery_water_valve_sp, ahu_10_heatRecovery_water_valve_sp, ahu_11_heatRecovery_water_valve_sp, ahu_4_heatRecovery_water_valve_sp, ahu_5_heatRecovery_water_valve_sp, ahu_12_heatRecovery_water_valve_sp","28":null,"29":null,"30":"ahu_102_air_return_temp_sensor","31":"ahu_102_air_return_temp_sensor","32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":null,"45":null,"46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":"ahu_23_enable_sched","55":"ahu_23_enable_sched","56":null,"57":null,"58":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","59":"ahu_sched_5, ahu_sched_6, sp_equation_of_time, sp_apparent_elevation, sp_elevation,wetBulb,dewPoint","60":null,"61":null,"62":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","63":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","64":null,"65":null,"66":null,"67":null,"68":"ahu_102_air_return_temp_sensor, ahu_231_air_return_temp_sensor","69":null,"70":null,"71":null,"72":null,"73":null},"mute_logs":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null,"15":null,"16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":null,"24":null,"25":null,"26":null,"27":null,"28":null,"29":null,"30":null,"31":null,"32":null,"33":null,"34":null,"35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","43":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","44":"all","45":"all","46":null,"47":null,"48":null,"49":null,"50":null,"51":null,"52":null,"53":null,"54":null,"55":null,"56":null,"57":null,"58":"dewPoint,wetBulb","59":"dewPoint,wetBulb","60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":null,"70":null,"71":null,"72":null,"73":null},"qa":{"1":"hvac_qa","2":"hvac_qa","3":"hvac_qa","4":"hvac_qa","5":"hvac_qa","6":"hvac_qa","7":"hvac_qa","8":"hvac_qa","9":"hvac_qa","10":"hvac_qa","11":"hvac_qa","12":"hvac_qa","13":"hvac_qa","14":"hvac_qa","15":"hvac_qa","16":"hvac_qa","17":"hvac_qa","18":"hvac_qa","19":"hvac_qa","20":"hvac_qa","21":"hvac_qa","22":"hvac_qa","23":"hvac_qa","24":"hvac_qa","25":"hvac_qa","26":"hvac_qa","27":"hvac_qa","28":"hvac_qa","29":"hvac_qa","30":"hvac_qa","31":"hvac_qa","32":"hvac_qa","33":"hvac_qa","34":"hvac_qa","35":"hvac_qa","36":"hvac_qa","37":"hvac_qa","38":"hvac_qa","39":"hvac_qa","40":"hvac_qa","41":"hvac_qa","42":"hvac_qa","43":"hvac_qa","44":"hvac_qa","45":"hvac_qa","46":"hvac_qa","47":"hvac_qa","48":"hvac_qa","49":"hvac_qa","50":"hvac_qa","51":"hvac_qa","52":"hvac_qa","53":"hvac_qa","54":"data_qa","55":"data_qa","56":"data_qa","57":"data_qa","58":"data_qa","59":"data_qa","60":"data_qa","61":"data_qa","62":"data_qa","63":"data_qa","64":"hvac_qa","65":"hvac_qa","66":"hvac_qa","67":"hvac_qa","68":"hvac_qa","69":"hvac_qa","70":"hvac_qa","71":"hvac_qa","72":"hvac_qa","73":"hvac_qa"}},"logs_link":"https://colab.research.google.com/drive/16lMaXuYFvn-BCOy2ZuAUO8aYpUyEneEQ"}'
json_data = '{"_comment_":"This is KPI settings","settings":{"mute_rules":false,"station_id":"10567","country":"Germany","state":"TH"},"rules":{"kpi_name":{"1":"run_time_cmd_hours","2":"run_time_hours","3":"ahu_air_return_temp_comfort_perc_18C-27C","4":"outside_air_temp_avg","5":"outside_air_temp_max","6":"HDD15","7":"CDD15","8":"ahu_co2_concentration_perc_<500ppm","9":"ahu_co2_concentration_avg","10":"ahu_air_return_temp_avg","11":"HDD15_COSTIC","12":"hot_water_temp_avg","13":"predicted_heat_kwh","14":"baseline_heat_kwh"},"alias_a":{"1":"enable_cmd","2":"enable_sensor","3":"ahu_air_return_temp_sensor","4":"air_temperature_1h","5":"air_temperature_1h","6":"air_temperature_1h","7":"air_temperature_1h","8":"ahu_co2_return_sensor","9":"ahu_co2_return_sensor","10":"ahu_air_return_temp_sensor","11":"costic_HDD_15C","12":"heatExchanger_secondaryLoop_hot_water_leaving_temp_sensor","13":"heatExchanger_primaryLoop_hot_water_entering_temp_sensor","14":"HDD_15C_COSTIC"},"alias_b":{"1":null,"2":null,"3":"ahu_fan_air_return_enable_cmd","4":null,"5":null,"6":null,"7":null,"8":"ahu_fan_air_return_enable_cmd","9":null,"10":null,"11":null,"12":null,"13":"heatExchanger_1_primaryLoop_hot_water_leaving_temp_sensor","14":null},"alias_c":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":"heatExchanger_2_primaryLoop_hot_water_leaving_temp_sensor","14":null},"alias_d":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":"heatExchanger_1_primaryLoop_hot_water_valve_sp","14":null},"alias_e":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":"heatExchanger_2_primaryLoop_hot_water_valve_sp","14":null},"alias_f":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null},"equation_1":{"1":"alias_a*24","2":"alias_a*24","3":"(1 if alias_a>18 and alias_a<27 else 0) if alias_b==1 else np.nan","4":null,"5":null,"6":"max(15-alias_a,0)","7":"max(alias_a-15,0)","8":"alias_a<500 and alias_b==1","9":null,"10":null,"11":"alias_a","12":null,"13":"((alias_a - alias_b)*alias_d) + ((alias_a - alias_c) * alias_e) ","14":"alias_a if holiday == 0 else np.nan"},"equation_2":{"1":null,"2":null,"3":"0 if pd.isna(value) else value","4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":"1000 * value / 12276.2","14":"54.05 * value * working_days - 2907.5"},"aggregation":{"1":"mean","2":"mean","3":"mean","4":"mean","5":"max","6":"mean","7":"mean","8":"mean","9":"mean","10":"mean","11":"mean","12":"mean","13":"sum","14":"mean"},"start_time":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null},"end_time":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":null,"10":null,"11":null,"12":null,"13":null,"14":null},"mute_logs":{"1":null,"2":null,"3":null,"4":null,"5":null,"6":null,"7":null,"8":null,"9":"ahu_2_co2_return_sensor_max, ahu_2_co2_return_sensor_min","10":null,"11":null,"12":null,"13":null,"14":null}},"logs_link":"https://colab.research.google.com/drive/16lMaXuYFvn-BCOy2ZuAUO8aYpUyEneEQ"}'
data1 = json.loads(json_data)
subcollection_ref.add(data1, document_id='qa_config')
# Out:
# (DatetimeWithNanoseconds(2023, 2, 20, 13, 54, 59, 718352, tzinfo=datetime.timezone.utc),
#  <google.cloud.firestore_v1.document.DocumentReference at 0x2681831dc50>)

# %%
import json

json_string = '{"name": "John", "age": 30, "address": {"city": "New York", "zip": "10001"}}'

# Load the JSON string into a Python object
data2 = json.loads(json_string)

# Get the character at position 10 of the "address" sub-object
char_at_10 = data[6]
print(char_at_10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[192], line 9
#       6 data2 = json.loads(json_string)
#       8 # Get the character at position 10 of the "address" sub-object
# ----> 9 char_at_10 = data[6]
#      10 print(char_at_10)
#
# KeyError: 6

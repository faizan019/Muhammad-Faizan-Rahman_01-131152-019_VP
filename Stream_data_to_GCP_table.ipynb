# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()

# %%
# Set up the data to be streamed
data = [
    ('2022-12-13T10:45:00', 'sp_zenith', 151515.9288238668 ),
    ('2022-12-13T10:45:00', 'air_temperature', 202020.9717641772)
]

# %%
# Set up the table and fields in BigQuery
table_id = 'outstanding-pen-377709.faizan_dataset.my_gbq_table010'
schema = [
    {"name":"time_local", "type":"DATETIME"},
    {"name": "alias", "type": "STRING"},
    {"name":"value", "type": "FLOAT"}
]

# %%
table = bigquery.Table(table_id, schema=schema)

# %%
# Stream the data into BigQuery
stream_data = client.insert_rows(table, data)

# %%
if stream_data == []:
    print('Data streamed successfully into BigQuery.')
else:
    print(f'Error streaming data into BigQuery: {stream_data}')
# Out:
# Data streamed successfully into BigQuery.

# %%
# 1-A GCP function to read a file from bucket
# 2-File is from the bucket
# 3-Do the ETL on the Value column
# 4-Store the transformed file in the bucket

#trigger through pubsub
#schedule the function through scheduler


#how to access gsheet through python

# %%
from google.cloud import storage
import pandas as pd
import io

def download_file_as_dataframe(bucket_name, file_name):
    # Create a GCS client object
    storage_client = storage.Client()

    # Get the GCS bucket object
    bucket = storage_client.bucket(bucket_name)

    # Get the GCS blob object for the file
    blob = bucket.blob(file_name)

    # Download the contents of the file as a byte string
    file_contents = blob.download_as_string()

    # Convert the byte string to a pandas dataframe
    df = pd.read_csv(io.StringIO(file_contents.decode('utf-8')))
    #df = pd.read_csv(blob.download_as_text())

    # Return the pandas dataframe
    return df

# %%
df = download_file_as_dataframe('faizan_bucket', 'main_data.csv')

# %%
print(df.head())
# Out:
#             time_local               alias       value
# 0  2022-12-23 01:00:00           sp_zenith  150.928824
# 1  2022-12-23 01:00:00                 lat   50.875698
# 2  2022-12-23 01:00:00  sp_apparent_zenith  150.928824
# 3  2022-12-23 01:00:00           dew_point    2.971764
# 4  2022-12-23 01:00:00                 dhi    0.000000

# %%
display(df)
# Out:
#                   time_local               alias       value
# 0        2022-12-23 01:00:00           sp_zenith  150.928824
# 1        2022-12-23 01:00:00                 lat   50.875698
# 2        2022-12-23 01:00:00  sp_apparent_zenith  150.928824
# 3        2022-12-23 01:00:00           dew_point    2.971764
# 4        2022-12-23 01:00:00                 dhi    0.000000
# ...                      ...                 ...         ...
# 1344757  2022-09-30 02:00:00          sp_azimuth   19.193106
# 1344758  2022-09-30 02:00:00       precipitation    0.000000
# 1344759  2022-09-30 02:00:00         cloud_cover   91.600000
# 1344760  2022-09-30 02:00:00           elevation  194.000000
# 1344761  2022-09-30 02:00:00                 lng   12.077743
#
# [1344762 rows x 3 columns]

# %%
#google-cloud-storage==1.42.0
#numpy==1.20.3
#pandas==1.3.0
from google.cloud import storage
import pandas as pd
import io


def read_file(bucket_name, file_name):
    # Create a GCS client object
    storage_client = storage.Client()

    # Get the GCS bucket object
    bucket = storage_client.bucket(bucket_name)

    # Get the GCS blob object for the file
    blob = bucket.blob(file_name)

    # Download the contents of the file as a byte string
    file_contents = blob.download_as_string()

    # Convert the byte string to a pandas dataframe
    df1 = pd.read_csv(io.StringIO(file_contents.decode('utf-8')))
    #df = pd.read_csv(blob.download_as_text())

    # Return the pandas dataframe
    return df1

df1 = read_file('faizan_bucket', 'main_data.csv')
display(df1)
df1['value'] = df1['value'].round(2)
df1['double_value'] = 4 * df1['value']
print('values after transformation')
print(df1['value'])
print(df1)
# Out:
#                   time_local               alias       value
# 0        2022-12-23 01:00:00           sp_zenith  150.928824
# 1        2022-12-23 01:00:00                 lat   50.875698
# 2        2022-12-23 01:00:00  sp_apparent_zenith  150.928824
# 3        2022-12-23 01:00:00           dew_point    2.971764
# 4        2022-12-23 01:00:00                 dhi    0.000000
# ...                      ...                 ...         ...
# 1344757  2022-09-30 02:00:00          sp_azimuth   19.193106
# 1344758  2022-09-30 02:00:00       precipitation    0.000000
# 1344759  2022-09-30 02:00:00         cloud_cover   91.600000
# 1344760  2022-09-30 02:00:00           elevation  194.000000
# 1344761  2022-09-30 02:00:00                 lng   12.077743
#
# [1344762 rows x 3 columns]
# values after transformation
# 0          150.93
# 1           50.88
# 2          150.93
# 3            2.97
# 4            0.00
#             ...
# 1344757     19.19
# 1344758      0.00
# 1344759     91.60
# ...

# %%
import pandas as pd
import requests


#def load_data():

    #bucket_name = 'faizan_bucket'
    #file_name = 'main_data.csv'

    # Load the file from GCS bucket into a DataFrame
    #df = pd.read_csv("gs://{}/{}".format(bucket_name, file_name))
df = pd.read_csv('gs://faizan_bucket/main_data.csv')
print(df['value'])
df['value'] = df['value'].round(2)
print('values after transformation')
print(df['value'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fsspec\registry.py:211, in get_filesystem_class(protocol)
#     210 try:
# --> 211     register_implementation(protocol, _import_class(bit["class"]))
#     212 except ImportError as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fsspec\registry.py:234, in _import_class(cls, minv)
#     233 mod, name = cls.rsplit(".", 1)
# --> 234 mod = importlib.import_module(mod)
#     235 return getattr(mod, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# ...

# %%
import pandas as pd
from google.cloud import storage
import os
import io
#os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'path/to/creds.json'


def gcp_csv_to_df(bucket_name, source_file_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(source_file_name)
    data = blob.download_as_bytes()
    df = pd.read_csv(io.BytesIO(data))
    print(f'Pulled down file from bucket {bucket_name}, file name: {source_file_name}')
    return df

gcp_csv_to_df('faizan_bucket', 'main_data.csv')
# Out:
# 0      150.93
# 1       50.88
# 2      150.93
# 3        2.97
# 4        0.00
# 5        0.00
# 6        0.00
# 7        0.00
# 8        3.84
# 9        4.58
# 10      24.14
# 11       0.00
# 12    1016.17
# 13       0.00
# 14      14.01
# 15      89.30
# 16      23.89
# 17       0.01
# 18     100.00
# Name: value, dtype: float64
# updated_value
# Pulled down file from bucket faizan_bucket, file name: file.csv
# "File transformed and uploaded to GCS bucket 'faizan_bucket' as 'transformed_file.csv'"

# %%
import pandas as pd
from google.cloud import storage
import os
import io
#os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'path/to/creds.json'


def gcp_csv_to_df(bucket_name, source_file_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(source_file_name)
    data = blob.download_as_bytes()
    df = pd.read_csv(io.BytesIO(data))
    df['value'] = df['value'].round(2)
    print(df['value'])
    
    #adding new column in a dataframe
    df['updated_value'] = 5*df['value']
    print('updated_value')
    #print(f'Pulled down file from bucket {bucket_name}, file name: {source_file_name}')
    
    #uploading transformed file back into the bucket
    updated_file = "transformed_" + source_file_name
    csv_data = df.to_csv(index=False)
    blob =bucket.blob(updated_file)
    blob.upload_from_string(csv_data)
    return "File transformed and uploaded to GCS bucket '{}' as '{}'".format(bucket_name, updated_file)
    
    
    
    #print(f'Pulled down file from bucket {bucket_name}, file name: {source_file_name}')
    #return df

gcp_csv_to_df('faizan_bucket', 'file.csv')
